# %% [markdown]
# # Standardized Test Analysis
# Author: [Ganesh Morye](#https://github.com/ganeshmorye)

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# SAT has been a mainstay and a pivotal point in a student's academic career for over a century. Performance of a student in the SAT test is influenced by a number of factors such as state of residence, family background, academic performance in the school, amongst other things. All these factors combined with the SAT scores guide the student's decision of selecting a major and also their degree level goal. Here we take a look at the SAT scores over the last 20 years to identify any trends in the scores and the factors influencing the student's performance in this test.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning : Set 1](#Data-Import-and-Cleaning-:-Set-1)
# - [Exploratory Data Analysis : Set 1](#Exploratory-Data-Analysis-:-Set-1)
# - [Data Dictionary : Set 1](#Data-Dictionary-:-Set-1)
# - [Data Visualization : Set 1](#Data-Visualization-:-Set-1)
# - [Data Import & Cleaning : Set 2](#Data-Import-and-Cleaning-:-Set-2)
# - [Exploratory Data Analysis : Set 2](#Exploratory-Data-Analysis-:-Set-2)
# - [Data Dictionary : Set 2](#Data-Dictionary-:-Set-2)
# - [Data Visualization : Set 2](#Data-Visualization-:-Set-2)
# - [Findings](#Findings)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)
# - [References](#References)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# Over the years SAT has undergone lot of changes to better reflect the changing landscapes in the education era. After its inception in 1926, it has evolved to meet the educational standards of America's best colleges and universities. The current form of modern-day SAT which comprises of two main sections, Reading/Writing and Match traces back its origin to 1952. Since then it has never remained static and kept evolving. 1994 saw the first time where students were allowed to use calculators which continues to this day. 2005 brought a big change to the way how SAT was scored. A new scoring system of 2400 points was introduced in 2005. This change was brought about to better reflect the value of clear and effective writing. An essay was added as a separate section in addition to the Verbal and Math sections. In 2016, this essay section was made optional and reading and writing sections were combined and took the form of Evidence based Reading and Writing section.

# %% [markdown]
# ***SAT changes over years***
#
# | SAT Changes Over Years      | 1994-2005 | 2006-2016     | 2017-Present     |
# | :---        |    :----:   |          ---: |      ---: |
# | Administration      | 1994-2005       | 2005-January 2016   |    March 2016-present |
# | Score Range   | 400-1600        | 600-2400      |     400-1600 |
# | Length of Test   | --        | 3 hours 45 minutes      |     3 hours (+50mins Optional Essay) |
# | Sections   | Critical Reading<br>Math        | Critical Reading<br>Writing+Essay<br>Mathematics     |     Evidence based Reading + Writing<br>Math<br>Essay (Optional) |

# %% [markdown]
# There are 2 sets of analysis being carried out in this project<br>
# 1. Set 1 conrresponds to data of SAT scores for each section and for all the states. These files follow the naming convention of sat_YEAR.xls. For eg sat_2000.xls correspond to SAT scores data for the year 2000.
# 2. Set 2 correspond to data of SAT scores classified into distinct categories such as Family Income, GPA etc. These files follow the naming convention of sat_student_characteristics_YEAR.xls.
# 3. Both dataset cover the period from 2000-2019 and downloaded in Excel format from National Center of Educational Statistics
# 4. These 2 datasets are individually processed in 2 python scripts:
#         a. process_sat_scores.py
#         b. process_sat_charac.py

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Michigan, Connecticut, New York, Delaware, Idaho, New Hampshire, Illinois, Colorado, District of Columbia, Maine, Rhode Island, Arizona, Minnesota, Tennessee, Florida, Texas, and Maryland provide options for taking SAT free of cost

# %% [markdown]
# ## Importing Libraries

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import os
from Matplotlib_rcParams import *
#sns.set()

# %%
imgs_folder = 'imgs'
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
imagefilespath = os.path.join(parentDirectory, imgs_folder)

boxplot_score_color = 'mediumturquoise'

dpi=400

# %% [markdown]
# ## Data Import and Cleaning : Set 1

# %%
# Code:
#Importing the dataframe of SAT scores for years 2000-2019
import process_sat_scores as pyfile

#Assigning the imported dataframe to a local variable
df = pyfile.df

# %% [markdown]
# ***Dataframe imported from process_sat_scores.py has the following 5 columns***
# 1. State - Representing the scores for a particular states. Data is available for all 50 states + Washington, D.C., and USA national average
# 2. Year - The year for which data was reported
# 3. Reading - Reading/Verbal section scores. 2000-2005 period had only 2 sections. Verbal+Math. An writing section was added from the year 2006-2016. From the year 2017 onwards, Writing section was made optional
# 4. Math - Math section scores
# 5. Writing - Writing section scores
# 6. Percent of Graduates taking SAT - Percent of graduates taking SAT

# %% [markdown]
# ### ***Note***<br>
# Writing Scores are available only for years 2006-2016.<br>Pre and post this period, Writing section was part of the Reading section. <br>Post 2016, this section is called as Evidence based Reading and Writing section.<br>
# For Analysis purposes, EBRW is named just as reading to be consistent with sections pre-2016 period in the dataframe and for scores to be in the range of 400-1600.

# %% [markdown]
# ## Exploratory Data Analysis : Set 1

# %%
#displaying first 5 rows of the dataframe
df.head(5)
# Out:
#            State       Year  Reading  Math  Writing  \
# 0  United States 2009-01-01      501   515    493.0
# 1        Alabama 2009-01-01      557   552    549.0
# 2         Alaska 2009-01-01      520   516    492.0
# 3        Arizona 2009-01-01      516   521    497.0
# 4       Arkansas 2009-01-01      572   572    556.0
#
#    Percent of Graduates taking SAT  Total
# 0                             46.0   1016
# 1                              7.0   1109
# 2                             46.0   1036
# 3                             26.0   1037
# 4                              5.0   1144

# %%
#checking for datatypes
df.dtypes
# Out:
# State                                      object
# Year                               datetime64[ns]
# Reading                                     int64
# Math                                        int64
# Writing                                   float64
# Percent of Graduates taking SAT           float64
# Total                                       int64
# dtype: object

# %%
#List States/USA for which data is available
df['State'].unique()
# Out:
# array(['United States', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
#df['Percent of Graduates taking SAT'] = df['Percent of Graduates taking SAT'].apply(lambda x: isinstance(x, str)).replace('---', 0)
df['Percent of Graduates taking SAT'] = df['Percent of Graduates taking SAT'].replace('---', 0)

# %%
#Inspecting the state with the lowest participation
df[df['Percent of Graduates taking SAT'] == min(df['Percent of Graduates taking SAT'])]
# Out:
#             State       Year  Reading  Math  Writing  \
# 347  North Dakota 2015-01-01      597   608    586.0
# 607  North Dakota 2016-01-01      585   594    560.0
#
#      Percent of Graduates taking SAT  Total
# 347                              1.9   1205
# 607                              1.9   1179

# %%
df.describe().T
# Out:
#                                   count         mean        std    min  \
# Reading                          1040.0   538.071154  41.942772  433.0
# Math                             1040.0   539.621154  41.631186  433.0
# Writing                           572.0   519.255245  41.297874  419.0
# Percent of Graduates taking SAT  1040.0    40.202849  31.871235    1.9
# Total                            1040.0  1077.692308  82.971681  866.0
#
#                                      25%     50%     75%     max
# Reading                           500.75   532.0   572.0   644.0
# Math                              506.00   530.0   570.0   655.0
# Writing                           483.00   509.0   561.0   592.0
# Percent of Graduates taking SAT     7.00    42.5    69.0   100.0
# Total                            1007.00  1059.0  1143.0  1298.0

# %% [markdown]
# ***Pivot Tables are used to do further EDA***<br>
# df_pivot_part - Pivot Table of Percent of Graduates taking SAT<br>
# df_pivot_math - Pivot Table of Math Scores taking SAT<br>
# df_pivot_total - Pivot Table of Math+Reading taking SAT<br>

# %%
#Pivot Table of Percent of Graduates taking SAT
df_pivot_part = df.pivot_table(values='Percent of Graduates taking SAT', index='Year', columns='State')
##df_pivot.index
#df_pivot['Michigan']

# %%
#inspecting the pivot table 
df_pivot_part.head()
# Out:
# State       Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Year
# 2000-01-01      9.0    50.0     34.0       6.0        49.0      32.0
# 2001-01-01      9.0    51.0     34.0       6.0        51.0      31.0
# 2002-01-01      9.0    52.0     36.0       5.0        52.0      28.0
# 2003-01-01     10.0    55.0     38.0       6.0        54.0      27.0
# 2004-01-01     10.0    53.0     32.0       6.0        49.0      27.0
#
# State       Connecticut  Delaware  District of Columbia  Florida  ...  \
# Year                                                              ...
# 2000-01-01         81.0      66.0                  89.0     55.0  ...
# 2001-01-01         82.0      67.0                  56.0     54.0  ...
# 2002-01-01         83.0      69.0                  76.0     57.0  ...
# 2003-01-01         84.0      73.0                  77.0     61.0  ...
# 2004-01-01         85.0      73.0                  77.0     67.0  ...
#
# ...

# %%
#Inspecting the statistics of pivot table and sorting them by the mean for each state
round(df_pivot_part.describe().T.sort_values(['mean']),2)
# Out:
#                       count   mean    std   min    25%    50%     75%     max
# State
# North Dakota           20.0   3.16   0.98   1.9   2.00   3.00    4.00    5.00
# South Dakota           20.0   3.52   0.78   2.8   3.00   3.00    4.00    5.00
# Mississippi            20.0   3.57   0.67   2.0   3.00   4.00    4.00    5.00
# Iowa                   20.0   3.65   0.99   2.0   3.00   3.00    5.00    5.00
# Arkansas               20.0   4.92   0.89   3.0   4.10   5.00    6.00    6.00
# Wisconsin              20.0   4.96   1.45   3.0   3.82   5.00    6.00    7.00
# Nebraska               20.0   5.44   2.10   3.0   3.65   5.00    8.00    9.00
# Missouri               20.0   5.53   1.78   3.0   4.00   5.00    7.25    8.00
# Utah                   20.0   5.56   1.13   3.0   4.88   6.00    6.00    7.00
# Louisiana              20.0   6.49   1.61   4.0   4.90   7.00    8.00    9.00
# Kansas                 20.0   6.79   1.89   4.0   5.18   7.00    9.00    9.00
# ...

# %%
#Pivot table of Math scores of all graduates taking SAT
df_pivot_math = df.pivot_table(values='Math', index='Year', columns='State')

# %%
round(df_pivot_math.describe().T.sort_values(['mean']),2)
# Out:
#                       count    mean    std    min     25%    50%     75%  \
# State
# District of Columbia   20.0  464.35  14.92  433.0  456.50  467.0  474.50
# Maine                  20.0  485.70  16.44  465.0  468.50  492.0  501.00
# Delaware               20.0  486.80  17.34  453.0  480.00  495.5  499.00
# Florida                20.0  493.15   7.24  475.0  489.75  497.0  498.00
# Georgia                20.0  494.50  10.98  485.0  488.50  491.0  495.25
# South Carolina         20.0  495.90  10.28  482.0  489.50  495.0  497.25
# Rhode Island           20.0  498.90   7.65  490.0  493.75  498.0  502.25
# Texas                  20.0  500.70   7.68  478.0  499.00  501.0  506.00
# West Virginia          20.0  504.50  13.46  460.0  501.00  507.0  511.00
# Pennsylvania           20.0  506.60  12.77  497.0  500.75  501.5  504.00
# Maryland               20.0  508.10  11.13  490.0  502.00  507.5  515.00
# New York               20.0  508.15  10.31  499.0  501.75  505.0  510.00
# ...

# %%
boxplot_order_part = df_pivot_part.describe().T.sort_values(['mean']).index
print(boxplot_order_part)
# Out:
# Index(['North Dakota', 'South Dakota', 'Mississippi', 'Iowa', 'Arkansas',
#        'Wisconsin', 'Nebraska', 'Missouri', 'Utah', 'Louisiana', 'Kansas',
#        'Wyoming', 'Oklahoma', 'Minnesota', 'Kentucky', 'Alabama', 'Tennessee',
#        'New Mexico', 'Illinois', 'Michigan', 'Ohio', 'Montana',
#        'West Virginia', 'Colorado', 'Arizona', 'Nevada', 'Idaho',
#        'United States', 'Alaska', 'Oregon', 'California', 'Texas',
#        'Washington', 'Hawaii', 'South Carolina', 'North Carolina', 'Indiana',
#        'Vermont', 'Florida', 'Virginia', 'Georgia', 'Pennsylvania', 'Maryland',
#        'Rhode Island', 'New Hampshire', 'New Jersey', 'New York', 'Delaware',
#        'Massachusetts', 'District of Columbia', 'Maine', 'Connecticut'],
#       dtype='object', name='State')

# %% [markdown]
# Since this dataset covers over 20 years of data during which
#  SAT underwent changes amongst other things with number of sections and score ranges, for ease of comparions
#  across this different "era" of SAT scores, total scores are taken as sum of Reading + Math section of scores

# %%
#Pivot table of Total SAT scores. 
df['Total'] = df['Math']+df['Reading']
df_pivot_total = df.pivot_table(values='Total', index='Year', columns='State')

# %%
#Inspecting the statistics of total scores as defined above for each state
round(df_pivot_total.describe().T.sort_values(['mean']),2)
# Out:
#                       count     mean    std     min      25%     50%      75%  \
# State
# District of Columbia   20.0   938.85  33.04   866.0   925.75   945.0   960.50
# Maine                  20.0   973.75  36.21   929.0   937.25   986.5  1006.00
# Delaware               20.0   975.15  36.22   908.0   965.00   994.0   998.25
# Texas                  20.0   990.05  20.63   944.0   979.75   992.0   995.50
# Florida                20.0   990.95  14.48   956.0   983.50   994.5   997.25
# South Carolina         20.0   991.00  29.17   966.0   974.75   983.0   987.50
# Georgia                20.0   992.40  28.51   972.0   977.00   982.0   989.25
# Rhode Island           20.0   999.30  18.03   981.0   988.75   994.5  1005.25
# New York               20.0  1004.45  25.80   983.0   989.25   998.0  1006.25
# Hawaii                 20.0  1008.45  38.42   978.0   987.25   998.0  1006.25
# Pennsylvania           20.0  1010.05  30.41   992.0   994.00   998.5  1003.25
# ...

# %% [markdown]
# ## Data Dictionary : Set 1

# %% [markdown]
# | Feature                         | Type           | Dataset                           | Description                                                                        |
# |---------------------------------|----------------|-----------------------------------|------------------------------------------------------------------------------------|
# | State                           | object         | sat_YEAR.xls                      | State for which the SAT scores are reported                                        |
# | Year                            | datetime64[ns] | sat_2000_2019.xls                 | Year for which the SAT scores are reported                                         |
# | Reading                         | int64          | sat_2000_2019.xls                 | Reading section scores                                                             |
# | Math                            | int64          | sat_2000_2019.xls                 | Math section scores                                                                |
# | Writing                         | float64        | sat_2000_2019.xls                 | Writing section scores                                                             |
# | Percent of Graduates taking SAT | float64        | sat_2000_2019.xls                 | Percent of Graduates taking SAT                                                    |

# %% [markdown]
# ## Data Visualization : Set 1

# %%
#sns.set()
fig, ax = plt.subplots(figsize=(20,8))
#plt.figure(figsize=(21,6))
#plt.plot(df_pivot.index, df_pivot['Michigan'])
ax.plot(df_pivot_part)
ax.legend(df_pivot_part.columns, loc='upper left', bbox_to_anchor=(0.025, -0.075), ncol = 11)
plt.title('TimeSeries Plot of Percent of Graduates Taking SAT', fontdict={'fontsize':18, 'fontweight':'bold'})
ax.xaxis.set_tick_params(which='major', bottom=True)
ax.yaxis.set_tick_params(which='major', left=True)
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.set_xlabel('Year', fontsize = 14, fontweight = 'bold')
ax.set_ylabel('Percent of Graduates Taking SAT', fontsize = 14, fontweight = 'bold')

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=200, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(20,25))
sns.boxplot(data=df_pivot_part, orient='h', order=list(boxplot_order_part), ax=ax, palette= 'OrRd')
ax.tick_params(labelrotation=0, color='white', labelsize=18)
ax.tick_params(axis='x', colors='brown')
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.set_xlabel('Percentage of Graduates Taking SAT', fontsize = 14, fontweight = 'bold', color='darksalmon')
plt.title('Percent of Graduates Taking SAT for Each State (2000-2019)', fontdict={'fontsize':18, 'fontweight':'bold'})

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=dpi, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,15))
sns.boxplot(data=df_pivot_part, orient='h', order=list(boxplot_order_part), ax=ax, palette= 'OrRd')
ax.tick_params(labelrotation=0, color='white', labelsize=12)
ax.tick_params(axis='x', colors='brown')
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.set_xlabel('Percentage of Graduates Taking SAT', fontsize = 14, fontweight = 'bold', color='darksalmon')

ax2 = ax.twiny()
sns.boxplot(data=df_pivot_math, orient='h', order=list(boxplot_order_part), ax=ax2, palette = 'Greens')
ax2.tick_params(labelrotation=0, color='darkgreen', labelsize=12)
ax2.tick_params(axis='x', colors='darkgreen')
ax2.xaxis.set_major_locator(ticker.MultipleLocator(25))
ax2.set_xlabel('Mean Math Scores', fontsize = 10, fontweight = 'bold', color='darkseagreen')

#ax.set_ylabel('')

plt.title('Percent of Graduates Taking SAT and Mean Math Scores for Each State (2000-2019)', fontdict={'fontsize':12, 'fontweight':'bold'})

output_img_filename = ax2.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=dpi, bbox_inches='tight')

# %%
#print(df['State'])
fig, ax = plt.subplots(figsize=(10,15))
sns.boxplot(data=df_pivot_part, orient='h', order=list(boxplot_order_part), ax=ax, palette= 'OrRd')
ax.tick_params(labelrotation=0, color='white', labelsize=12)
ax.tick_params(axis='x', colors='brown')
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.set_xlabel('Percentage of Graduates Taking SAT', fontsize = 12, fontweight = 'bold', color='darksalmon')

ax2 = ax.twiny()
sns.boxplot(data=df_pivot_total, orient='h', order=list(boxplot_order_part), ax=ax2, palette = 'Greens')
ax2.tick_params(labelrotation=0, color='darkgreen', labelsize=12)
ax2.tick_params(axis='x', colors='darkgreen')
ax2.xaxis.set_major_locator(ticker.MultipleLocator(50))
ax2.set_xlabel('Mean Total Scores', fontsize = 14, fontweight = 'bold', color='darkseagreen')

plt.title('Percent of Graduates Taking SAT and Mean Total Scores for Each State (2000-2019)', fontdict={'fontsize':12, 'fontweight':'bold'})

output_img_filename = ax2.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=dpi, bbox_inches='tight')

# %% [markdown]
# Certain states have incentivized taking SAT tests. This reflect in a very high participation rates of graduates taking SAT. States with higher participation rates have lower average SAT scores. This is just an artifact of the data being skewed towards high performing states preferring to take SAT driving the states average higher for states with lower participation rates.

# %% [markdown]
# ## Data Import & Cleaning : Set 2

# %% [markdown]
# ***Dataframe imported from process_sat_charac.py has the following 6 columns***
# 1. Characteristics - This column is a categorical label associated "Child" characteristics used for clasifying SAT scores
# 2. Category - This column is a categorical label associated "Parent" characteristics used for classifying SAT scores
# 3. Year - Year the scores were reported
# 4. Reading - Reading/Verbal section scores. 2000-2005 period had only 2 sections. Verbal+Math. An writing section was added from the year 2006-2016. From the year 2017 onwards, Writing section was made optional
# 5. Math - Math section scores
# 6. Writing - Writing section scores
# 7. Percent Distribution - Percent Distribution of students belonging to a particular "Child" category. All the Child categories add upto 100 under a Parent category

# %%
#Importing data
import process_sat_charac as pyfile2
df2 = pyfile2.df

# %%
#cleaning data
df2 = df2.replace(0, np.nan)
df2
# Out:
#              Characteristics                             Category       Year  \
# 0               All students                         All students 2004-01-01
# 1                 Top decile                     High school rank 2004-01-01
# 2              Second decile                     High school rank 2004-01-01
# 3            Second quintile                     High school rank 2004-01-01
# 4             Third quintile                     High school rank 2004-01-01
# ...                      ...                                  ...        ...
# 1309  No high school diploma  Highest level of parental education 2009-01-01
# 1310     High school diploma  Highest level of parental education 2009-01-01
# 1311      Associate's Degree  Highest level of parental education 2009-01-01
# 1312       Bachelor's degree  Highest level of parental education 2009-01-01
# 1313         Graduate degree  Highest level of parental education 2009-01-01
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis : Set 2

# %%
# checking for dtypes and null values
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1314 entries, 0 to 1313
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Characteristics          1314 non-null   object
#  1   Category                 1314 non-null   object
#  2   Year                     1314 non-null   datetime64[ns]
#  3   Reading                  1284 non-null   float64
#  4   Math                     1284 non-null   float64
#  5   Writing                  791 non-null    float64
#  6   Percentage Distribution  999 non-null    float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 72.0+ KB

# %%
df2.describe()
# Out:
#            Reading         Math     Writing  Percentage Distribution
# count  1284.000000  1284.000000  791.000000               999.000000
# mean    504.737539   511.030374  489.190898                12.402275
# std      49.466921    48.116835   48.815102                17.130822
# min     375.000000   390.000000  363.000000                 0.051365
# 25%     467.000000   477.000000  453.500000                 1.763823
# 50%     510.000000   512.000000  493.000000                 7.000000
# 75%     541.000000   540.000000  525.000000                18.000000
# max     626.000000   650.000000  599.000000               100.000000

# %% [markdown]
# Since this dataset covers over 20 years of data during which
#  SAT underwent changes amongst other things with number of sections and score ranges, for ease of comparions
#  across this different "era" of SAT scores, total scores are taken as sum of Reading + Math section of scores

# %%
df2['Total'] = df2['Reading'] + df2['Math']

# %%
#Pivot table of Reading SAT scores
df2_pivot = df2.pivot_table(values='Reading', index = 'Year', columns = ['Category', 'Characteristics'])

# %%
df2_pivot.head(1)
# Out:
# Category        All students  Degree-level goal                    \
# Characteristics All students Associate's Degree Bachelor's degree
# Year
# 2000-01-01             505.0              420.0             478.0
#
# Category                                                        \
# Characteristics Certificate program Doctoral or related degree
# Year
# 2000-01-01                    439.0                      547.0
#
# Category                                                 Family income  \
# Characteristics Master's degree  Other Undecided $100,000, to $150,000
# Year
# 2000-01-01                515.0  442.0     508.0                 558.0
#
# Category                               ... Intended college major  \
# Characteristics $150,000, to $200,000  ...             Psychology
# Year                                   ...
# 2000-01-01                        NaN  ...                    NaN
#
# Category                                                   \
# ...

# %%
#Pivot table of TOTAL SAT scores
df2_pivot_total = df2.pivot_table(values='Total', index = 'Year', columns = ['Category', 'Characteristics'])
df2_pivot_total.head(2)
# Out:
# Category        All students  Degree-level goal                    \
# Characteristics All students Associate's Degree Bachelor's degree
# Year
# 2000-01-01            1019.0              839.0             961.0
# 2001-01-01            1020.0              835.0             961.0
#
# Category                                                        \
# Characteristics Certificate program Doctoral or related degree
# Year
# 2000-01-01                    892.0                     1101.0
# 2001-01-01                    898.0                     1101.0
#
# Category                                                 Family income  \
# Characteristics Master's degree  Other Undecided $100,000, to $150,000
# Year
# 2000-01-01               1041.0  896.0    1022.0                1129.0
# 2001-01-01               1042.0  887.0    1028.0                1126.0
#
# Category                               ... Intended college major  \
# Characteristics $150,000, to $200,000  ...             Psychology
# ...

# %%
boxplot_order_part = ['Top decile', 'Second decile', 'Second quintile', 'Third quintile', 'Fourth quintile',	'Fifth quintile', 'Bottom three quintiles ']

# %%
#Extracting data for the Parent category of High School Rank
df2_total_high_school_rank = df2_pivot_total['High school rank']
df2_total_high_school_rank.head(2)
# Out:
# Characteristics  Bottom three quintiles   Fifth quintile  Fourth quintile  \
# Year
# 2000-01-01                           NaN           809.0            844.0
# 2001-01-01                           NaN           808.0            840.0
#
# Characteristics  Second decile  Second quintile  Third quintile  Top decile
# Year
# 2000-01-01              1071.0            993.0           908.0      1197.0
# 2001-01-01              1066.0            987.0           906.0      1195.0

# %% [markdown]
# ## Data Dictionary : Set 2

# %% [markdown]
# | Feature                         | Type           | Dataset                           | Description                                                                        |
# |---------------------------------|----------------|-----------------------------------|------------------------------------------------------------------------------------|
# | Characteristics                 | object         | sat_characteristics_2000_2019.xls | Characteristics of the particular Category such as gpa, family income etc          |
# | Category                        | object         | sat_characteristics_2000_2019.xls | Category under which the scores are reported                                       |
# | Year                            | datetime64[ns] | sat_characteristics_2000_2019.xls | Year for which the SAT scores are reported                                         |
# | Reading                         | float64        | sat_characteristics_2000_2019.xls | Reading section scores                                                             |
# | Math                            | float64        | sat_characteristics_2000_2019.xls | Math section scores                                                                |
# | Writing                         | float64        | sat_characteristics_2000_2019.xls | Writing section scores                                                             |
# | Percentage Distribution         | float64        | sat_characteristics_2000_2019.xls | Percent distribution of students beloging within a particular reporting   category |

# %% [markdown]
# ## Data Visualization : Set 2

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.boxplot(data=df2_total_high_school_rank, order = boxplot_order_part, orient='h', ax=ax, color= boxplot_score_color)
ax.tick_params(labelrotation=0, labelsize = 12)
ax.xaxis.set_major_locator(ticker.MultipleLocator(50))
ax.set_xlabel('Total SAT Score', fontsize = 12, fontweight = 'bold')
ax.set_ylabel('High School Rank', fontsize = 12, fontweight = 'bold')
ax.set_title('Distribution of Total SAT Scores by High School Rank Category', fontsize = 12, fontweight = 'bold')

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=100, bbox_inches='tight')

# %%
#Dataframe to extract High school GPA
df2_total_gpa = df2_pivot_total['High school grade point average']
df2_total_gpa.head(2)
# Out:
# Characteristics  A (93-96)  A+ (97-100)  A- (90-92)  B (80-89)  C (70-79)  \
# Year
# 2000-01-01          1149.0       1238.0      1093.0      968.0      854.0
# 2001-01-01          1147.0       1235.0      1092.0      968.0      853.0
#
# Characteristics  D, E, or F (below 70)  No response
# Year
# 2000-01-01                       811.0          NaN
# 2001-01-01                       807.0          NaN

# %%
df2_total_gpa.columns
# Out:
# Index(['A (93-96)', 'A+ (97-100)', 'A- (90-92)', 'B (80-89)', 'C (70-79)',
#        'D, E, or F (below 70)', 'No response'],
#       dtype='object', name='Characteristics')

# %%
#Order in which y-axis labels are ordered
boxplot_order_part = ['A+ (97-100)', 'A (93-96)', 'A- (90-92)', 'B (80-89)', 'C (70-79)', 'D, E, or F (below 70)', 'No response']

# %%
#sns.set()
fig, ax = plt.subplots(figsize=(10,5))
sns.boxplot(data=df2_total_gpa, order = boxplot_order_part, orient='h', ax=ax, color= boxplot_score_color)
ax.tick_params(labelrotation=0, labelsize=12)
ax.xaxis.set_major_locator(ticker.MultipleLocator(50))
ax.set_xlabel('Total SAT Score', fontsize = 12, fontweight = 'bold')
ax.set_ylabel('High School GPA', fontsize = 12, fontweight = 'bold')
ax.set_title('Distribution of Total SAT Scores by High School GPA', fontsize = 12, fontweight = 'bold')

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=100, bbox_inches='tight')

# %% [markdown]
# High school GPA captures very well how well the student will perform in the SAT testing. This bodes very well for the philosophy of standardized testing as it captures the high school level performance across a wide variety of school districts who vary widely in their resources for providing good quality education. SAT tends to replicate high school performance. This shows 2 things:
# 1. Schools are doing a good job to prepare their students in terms of college-readiness
# 2. Testing across schools all over the nation is robust enough that they act as a good proxy for SAT test scores

# %%
#dataframe to extract total family income category
df2_total_family_income = df2_pivot_total['Family income']
df2_total_family_income.head(2)
# Out:
# Characteristics  $100,000, to $150,000  $150,000, to $200,000  \
# Year
# 2000-01-01                      1129.0                    NaN
# 2001-01-01                      1126.0                    NaN
#
# Characteristics  $20,000, to $40,000  $40,000, to $60,000  \
# Year
# 2000-01-01                     966.0               1017.0
# 2001-01-01                     959.0               1012.5
#
# Characteristics  $60,000, to $80,000  $80,000 to $100,000  Less than $20,000  \
# Year
# 2000-01-01                    1046.5               1079.0              889.5
# 2001-01-01                    1042.0               1074.0              881.0
#
# Characteristics  More than $200,000
# Year
# 2000-01-01                      NaN
# 2001-01-01                      NaN

# %%
df2_total_family_income.columns
# Out:
# Index(['$100,000, to $150,000', '$150,000, to $200,000', '$20,000, to $40,000',
#        '$40,000, to $60,000', '$60,000, to $80,000', '$80,000 to $100,000',
#        'Less than $20,000', 'More than $200,000'],
#       dtype='object', name='Characteristics')

# %%
#Order in which y-axis labels are ordered

boxplot_order_part = ['Less than $20,000', '$20,000, to $40,000', '$40,000, to $60,000', '$60,000, to $80,000', '$80,000 to $100,000', 
'$100,000, to $150,000', '$150,000, to $200,000', 'More than $200,000']

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.boxplot(data=df2_total_family_income, order=boxplot_order_part[::-1], orient='h', ax=ax, color= boxplot_score_color)
ax.tick_params(labelrotation=0, labelsize=12)
ax.xaxis.set_major_locator(ticker.MultipleLocator(50))
ax.set_xlabel('Total SAT Score', fontsize = 12, fontweight = 'bold')
ax.set_ylabel('Family Income', fontsize = 12, fontweight = 'bold')
ax.set_title('Distribution of Total SAT Scores by Family Income', fontsize = 12, fontweight = 'bold')

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=100, bbox_inches='tight')

# %% [markdown]
# Families with lot of resources can afford to provide their kids with the best education. This "investment" pays off very well as their kids also end up getting a "higher return on investment" in the form of higher SAT scores.

# %%
#dataframe to extract highest level of parental education category
df2_total_parent_education = df2_pivot_total['Highest level of parental education']
df2_total_parent_education.head(2)
# Out:
# Characteristics  Associate's Degree  Bachelor's degree  Graduate degree  \
# Year
# 2000-01-01                    979.0             1058.0           1124.0
# 2001-01-01                    980.0             1058.0           1126.0
#
# Characteristics  High school diploma  No high school diploma
# Year
# 2000-01-01                     949.0                   855.0
# 2001-01-01                     948.0                   849.0

# %%
df2_total_parent_education.columns
# Out:
# Index(['Associate's Degree', 'Bachelor's degree', 'Graduate degree',
#        'High school diploma', 'No high school diploma'],
#       dtype='object', name='Characteristics')

# %%
#Order in which y-axis labels are ordered

boxplot_order_part = ['No high school diploma', 'High school diploma', "Associate's Degree", "Bachelor's degree", 'Graduate degree',
       ]

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.boxplot(data=df2_total_parent_education,order= boxplot_order_part[::-1], orient='h', ax=ax, color= boxplot_score_color)
ax.tick_params(labelrotation=0, labelsize=12)
ax.xaxis.set_major_locator(ticker.MultipleLocator(50))
ax.set_xlabel('Total SAT Score', fontsize = 12, fontweight = 'bold')
ax.set_ylabel('Highest Level of Parental Education', fontsize = 12, fontweight = 'bold')
ax.set_title('Distribution of Total SAT Scores by Highest Level of Parental Education', fontsize = 18, fontweight = 'bold')

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=100, bbox_inches='tight')

# %% [markdown]
# Level of parental education strongly influences how well the student's do in their SAT testing. Higher the level of parental education, higher the student's score in their SAT scores. This also correlates to the family income plot. Families with advanced degree also generally belong to higher income group

# %%
#dataframe to extract Degree-Level goal of participating graduates
df2_total_degree_goal = df2_pivot_total['Degree-level goal']
df2_total_degree_goal.head(2)
# Out:
# Characteristics  Associate's Degree  Bachelor's degree  Certificate program  \
# Year
# 2000-01-01                    839.0              961.0                892.0
# 2001-01-01                    835.0              961.0                898.0
#
# Characteristics  Doctoral or related degree  Master's degree  Other  Undecided
# Year
# 2000-01-01                           1101.0           1041.0  896.0     1022.0
# 2001-01-01                           1101.0           1042.0  887.0     1028.0

# %%
df2_total_degree_goal.columns
# Out:
# Index(['Associate's Degree', 'Bachelor's degree', 'Certificate program',
#        'Doctoral or related degree', 'Master's degree', 'Other', 'Undecided'],
#       dtype='object', name='Characteristics')

# %%
#Order in which y-axis labels are ordered

boxplot_order_part = ["Associate's Degree", 'Certificate program', "Bachelor's degree", "Master's degree", 
       'Doctoral or related degree', 'Other', 'Undecided']

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.boxplot(data=df2_total_degree_goal, order= boxplot_order_part[::-1], orient='h', ax=ax, color= boxplot_score_color)
ax.tick_params(labelrotation=0, labelsize=12)
ax.xaxis.set_major_locator(ticker.MultipleLocator(50))
ax.set_xlabel('Total SAT Score', fontsize = 12, fontweight = 'bold')
ax.set_ylabel('Degree Level Goal', fontsize = 12, fontweight = 'bold')
ax.set_title('Distribution of Total SAT Scores by Degree Level Goal', fontsize = 18, fontweight = 'bold')

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=100, bbox_inches='tight')

# %% [markdown]
# Student's doing very well in their SAT tests gravitate towards advanced degrees.

# %%
df2_total_intended_college_major = df2_pivot_total['Intended college major']
df2_total_intended_college_major.head(2)
# Out:
# Characteristics  Agriculture and Related Sciences  Architecture  \
# Year
# 2000-01-01                                  976.0        1018.0
# 2001-01-01                                  971.0        1014.0
#
# Characteristics  Area, Ethnic, Cultural, and Gender Studies  \
# Year
# 2000-01-01                                              NaN
# 2001-01-01                                              NaN
#
# Characteristics  Arts: Visual/Performing  Biological and Biomedical Sciences  \
# Year
# 2000-01-01                        1020.0                              1092.0
# 2001-01-01                        1019.0                              1094.0
#
# Characteristics  Business and Commerce  Communications and Journalism  \
# Year
# 2000-01-01                       997.0                         1031.0
# 2001-01-01                      1000.0                         1033.0
#
# Characteristics  Communications and journalism  \
# Year
# 2000-01-01                                 NaN
# ...

# %%
boxplot_order_part = list(df2_total_intended_college_major.mean().T.sort_values(ascending=False).index)

# %%
fig, ax = plt.subplots(figsize=(10,15))
sns.boxplot(data=df2_total_intended_college_major, order= boxplot_order_part, orient='h', ax=ax, color= boxplot_score_color)
ax.tick_params(labelrotation=0, labelsize = 12)
ax.xaxis.set_major_locator(ticker.MultipleLocator(50))
ax.set_xlabel('Total SAT Score', fontsize = 12, fontweight = 'bold')
ax.set_ylabel('Intended College Major', fontsize = 12, fontweight = 'bold')
ax.set_title('Distribution of Total SAT Scores by Intended College Major', fontsize = 12, fontweight = 'bold');

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=200, bbox_inches='tight')

# %% [markdown]
# Boxplot shows how the SAT scores trend with the Intended college major of graudating students. Students with higher SAT scores tend to gravitate towards STEM, languages majors

# %%
#Investigating the variability in Idaho's test scores
df_pivot_part['Idaho']
# Out:
# Year
# 2000-01-01     16.0
# 2001-01-01     17.0
# 2002-01-01     18.0
# 2003-01-01     18.0
# 2004-01-01     20.0
# 2005-01-01     21.0
# 2006-01-01     19.0
# 2007-01-01     19.0
# 2008-01-01     18.0
# 2009-01-01     18.0
# 2010-01-01     19.0
# 2011-01-01     20.0
# 2012-01-01     20.0
# 2013-01-01     99.0
# 2014-01-01    100.0
# 2015-01-01     99.9
# 2016-01-01     99.9
# 2017-01-01     93.0
# 2018-01-01    100.0
# 2019-01-01    100.0
# Name: Idaho, dtype: float64

# %%
#sns.set()
fig, ax = plt.subplots(figsize=(20,8))
#plt.figure(figsize=(21,6))
#plt.plot(df_pivot.index, df_pivot['Michigan'])
ax.plot(df_pivot_part['Idaho'])
ax.legend('Idaho', loc='upper left', bbox_to_anchor=(0.025, -0.075), ncol = 12)
plt.title('TimeSeries Plot of Percent of Graduates Taking SAT in Idaho', fontdict={'fontsize':18, 'fontweight':'bold'})
ax.xaxis.set_tick_params(which='major', bottom=True)
ax.yaxis.set_tick_params(which='major', left=True)
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.set_xlabel('Year', fontsize = 14, fontweight = 'bold')
ax.set_ylabel('Percent of Graduates Taking SAT in Idaho', fontsize = 14, fontweight = 'bold')

output_img_filename = ax.get_title() + '.png'
output_img_filename = output_img_filename.replace(" ", "_")
fig.savefig(os.path.join(imagefilespath, output_img_filename), dpi=dpi, bbox_inches='tight')

# %% [markdown]
# Idaho started picking up the tab of SAT fees in 2014-2015 which corresponded to 100% participation rates in the SAT testing

# %% [markdown]
# ## Findings
# 1. On the lower end, percentages have varied between 5-10% for 20 states with the Dakotas having the lowest rates
# 2. D.C., Maine, Connecticut have participation rates over 80%
# 3. Idaho started covering the fees of SAT tests from 2013-2014 which saw the states SAT participation rates jump from 20% to ~100% in 2014
# 4. In general, states with lower participation rates tend to have higher scores and wider variability
# 5. SAT scores should be adjusted for their corresponding participation rates for a real comparative analysis
# 6. Students performing better in school tend to have higher SAT scores
# 7. Average SAT scores for the top performing students are around 1200 and at the lower end students score around 800
# 8. Kids belonging to families with higher income and advanced degrees perform significantly better than those belonging to low-income and no high school diploma families
# 9. Students with higher SAT scores tend to aim for more advanced degrees in their careers

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# 1. Certain states which have started covering the SAT test fees have a seen an increase in the student participation in the recent years
# 2. Students with a good academic performance also perform better in the SAT test. Although this should not come as a surprise, it does show that SAT does its job well as a standardized metric to evaluate student’s academic performance across wide ranges of schools, districts, states
# 3. Family’s background plays a huge role in the student’s performance in the SAT. If the colleges started to rely on a standardized metric as a sole admission’s criteria, it will end up severely disadvantaging the students coming from low-income families
# 4. Student’s academic choices and their acceptance into a particular major are greatly influenced by their SAT scores

# %% [markdown]
# ## References
# [WHAT IS THE SAT®?](https://www.kaptest.com/sat/what-is-the-sat) <br>
# [Here's how the SAT has changed over the past 90 years and where it might be heading](https://www.insider.com/how-the-sat-has-changed-over-the-past-90-years-2019-8#the-us-army-a-eugenics-professor-and-thousands-of-universities-came-together-to-give-birth-to-the-worlds-biggest-standardized-exam-1)<br>
# [Why Is the SAT Falling Out of Favor?](https://www.nytimes.com/2020/05/23/us/SAT-ACT-abolish-debate-california.html#:~:text=Critics%20of%20the%20tests%20cite,white%20and%20Asian%2DAmerican%20students.&text=Critics%20also%20say%20the%20tests,private%20coaching%20and%20test%20prep.)<br>
# [How the SAT failed America](https://www.forbes.com/sites/susanadams/2020/09/30/the-forbes-investigation-how-the-sat-failed-america/?sh=51586cea53b5)<br>
# [States That Provide A Free ACT/ SAT Test](https://www.collegeraptor.com/getting-in/articles/act-sat/states-act-sat-given-free/)<br>
